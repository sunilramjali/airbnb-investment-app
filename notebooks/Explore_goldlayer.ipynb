# %%
CREATE TABLE AIRBNB_INVESTMENT_DB.GOLD.INVESTMENT_SCORES AS
SELECT * FROM SHARED_AI_GOLD.GOLD.INVESTMENT_SCORES;

# %%
CREATE TABLE AIRBNB_INVESTMENT_DB.GOLD.AI_OUTPUTS AS
SELECT * FROM SHARED_AI_GOLD.GOLD.AI_OUTPUTS;
